# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
PATH_BASE = '/content/drive/My Drive/Appunti delle lezioni/2Anno2Semestre/Digital Image Processing/surface_normal_estimation_us/'
PATH_EXPORT = '/content/drive/My Drive/Appunti delle lezioni/2Anno2Semestre/Digital Image Processing/npy_files/'

# %%
immagini_db = np.load(PATH_BASE + 'input_imgs_dataset.npy')

# %%
normali = np.load(PATH_BASE + '/normals_orig.npy')

# %%
np.savez_compressed(PATH_EXPORT + "dataset_iniziale.npz", immagini_db = immagini_db, normali = normali)

# %%
loaded = np.load(PATH_EXPORT + "dataset_iniziale.npz")
x2 = loaded["immagini_db"]

# %%
type(x2)
# Out:
# numpy.ndarray

# %%
x2.shape
# Out:
# (1446, 195, 260, 3)
