# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
PATH_BASE = '/content/drive/My Drive/Appunti delle lezioni/2Anno2Semestre/Digital Image Processing/surface_normal_estimation_us/'

# %% [markdown]
# # Confronto su labels ottenute
# Due modalità
#
#
# *   Ricompilazione dei clustering, dopo aver fatto un reshape su immagine di input rappresentante le normali (**recomp**)
# *   Nearest Neighbour su output classificazione normali a posteriori (**post**)

# %%
reshaped_labels_recomp = np.load(PATH_BASE + "normals_centroid_labels_nneigh.npy")

# %%
reshaped_labels = np.load(PATH_BASE + "normals_centroid_labels.npy")

# %%
reshaped_labels_post = tf.image.resize(reshaped_labels, [320,320], method='nearest').numpy()

# %%
reshaped_labels.shape
# Out:
# (1446, 195, 260)

# %% [markdown]
# ## Conteggio classificazioni differenti

# %%
def mismatchingPixels(clust1, clust2):
  assert clust1.shape == clust2.shape
  for n in range(0, clust1.shape[0]):
    for i in range(0, clust1.shape[1]):
      for j in range(0, clust1.shape[2]):
